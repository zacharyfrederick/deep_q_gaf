# %%
import pandas as pd
import numpy as np

# %%
open_ = pd.read_csv('/Users/zacharyfrederick/Documents/GitHub/senior_project/data/processed/nvda/close.csv', index_col='Date')
high = pd.read_csv('/Users/zacharyfrederick/Documents/GitHub/senior_project/data/processed/nvda/high.csv', index_col='Date')

# %%
df = pd.merge(open_, high)

# %%
open_
# Out:
#              0         1         2         3         4         5         6  \
# Date
# NaN  -0.637992 -0.680617 -0.485039  0.425446 -0.310398 -0.730098 -0.401523
# NaN  -0.730492 -0.715973 -0.756203 -0.568099  0.367088 -0.394621 -0.802163
# NaN  -0.803391 -0.768188 -0.754557 -0.792229 -0.614031  0.313536 -0.446293
# NaN  -0.036020 -0.465764 -0.414629 -0.395405 -0.449302 -0.211087  0.694255
# NaN   1.000000  0.490363  0.155461  0.202569  0.219700  0.170878  0.369593
# ...        ...       ...       ...       ...       ...       ...       ...
# NaN  -0.822543 -0.567429 -0.686725  0.297873 -0.206858 -0.649916 -0.796186
# NaN  -0.846992 -0.834973 -0.585580 -0.702703  0.276594 -0.228541 -0.666639
# NaN  -0.869625 -0.858517 -0.846914 -0.603327 -0.718234  0.255319 -0.249970
# NaN  -0.796288 -0.997779 -0.999006 -0.999750 -0.942714 -0.982654 -0.319149
# NaN  -0.706655 -0.997676 -0.795360 -0.781789 -0.767745 -0.490641 -0.618176
#
# ...

# %%
high
# Out:
#              0         1         2         3         4         5         6  \
# Date
# NaN  -0.033356 -0.144988 -0.147082  0.454783  0.695214 -0.101098  0.157760
# NaN  -0.528956 -0.291090 -0.396319 -0.398262  0.208581  0.485306 -0.355337
# NaN  -0.269078 -0.403101 -0.152304 -0.261945 -0.263988  0.345331  0.604534
# NaN   0.893969  0.404877  0.270948  0.511029  0.411631  0.409700  0.863350
# NaN   1.000000  0.705370  0.386793  0.283745  0.465167  0.391872  0.390421
# ...        ...       ...       ...       ...       ...       ...       ...
# NaN  -0.325698 -0.287431 -0.115064 -0.115064  0.580647 -0.205546 -0.287431
# NaN  -0.592090 -0.464172 -0.428194 -0.263134 -0.263134  0.451614 -0.350375
# NaN  -0.999480 -0.899382 -0.823415 -0.799941 -0.682350 -0.682350 -0.016130
# NaN  -0.981269 -0.996738 -0.844320 -0.754141 -0.727135 -0.595522 -0.595522
# NaN  -0.849636 -0.983696 -0.957127 -0.981849 -0.942162 -0.927929 -0.848208
#
# ...
